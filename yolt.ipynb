# %%
from ultralytics import YOLO
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
import os, sys
import glob

# %%
DATA_DIR = os.path.join(os.path.abspath(".."), "cons454_project/data/")

# %%
model = YOLO("yolov8n.pt")
input_folder = DATA_DIR + "edge_cases/"
output_folder = DATA_DIR + "yolt_results/"
os.makedirs(output_folder, exist_ok=True)
image_paths = glob.glob(os.path.join(input_folder, "*.*"))

# %%
for image_path in image_paths:
    filename = os.path.basename(image_path)
    result_path = os.path.join(output_folder, filename)

    results = model(image_path)
    results[0].save(filename=result_path)

    input_img = mpimg.imread(image_path)
    result_img = mpimg.imread(result_path)

    fig, axes = plt.subplots(1, 2, figsize=(10, 5))
    axes[0].imshow(input_img)
    axes[0].axis('off')
    axes[0].set_title('Original Image')

    axes[1].imshow(result_img)
    axes[1].axis('off')
    axes[1].set_title('YOLO Result')

    plt.tight_layout()
    plt.show()
# Out:
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08090011.JPG: 384x640 (no detections), 252.4ms
# Speed: 6.0ms preprocess, 252.4ms inference, 2.1ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08090031.JPG: 384x640 1 cat, 438.3ms
# Speed: 10.3ms preprocess, 438.3ms inference, 2.9ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08110106.JPG: 384x640 3 horses, 438.3ms
# Speed: 10.1ms preprocess, 438.3ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08110132.JPG: 384x640 1 cat, 303.4ms
# Speed: 7.5ms preprocess, 303.4ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08110133.JPG: 384x640 1 person, 266.6ms
# Speed: 8.3ms preprocess, 266.6ms inference, 3.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08180341.JPG: 384x640 (no detections), 245.2ms
# Speed: 6.3ms preprocess, 245.2ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08180358.JPG: 384x640 1 cow, 1 elephant, 371.1ms
# Speed: 8.0ms preprocess, 371.1ms inference, 2.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08200416.JPG: 384x640 (no detections), 398.7ms
# Speed: 6.0ms preprocess, 398.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\08230520.JPG: 384x640 1 dog, 1 elephant, 453.4ms
# Speed: 7.4ms preprocess, 453.4ms inference, 5.0ms postprocess per image at shape (1, 3, 384, 640)
# image 1/1 C:\Users\benso\Documents\VSCode\cons454_project\data\edge_cases\EK000448.JPG: 480x640 (no detections), 437.6ms
# Speed: 8.9ms preprocess, 437.6ms inference, 1.0ms postprocess per image at shape (1, 3, 480, 640)
